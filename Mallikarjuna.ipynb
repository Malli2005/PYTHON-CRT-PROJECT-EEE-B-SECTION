# %%
import math
class Threephasepower:
  def __init__(self,v,i,p.f):
    self,v=v
    self,i=i
    self,p.f=p.f
  def power(self):
    return math.sqrt(3)*self
  self.pf
  tp=threephase(400,50,0.9)
print("three-phase power:", round(tp.power())
# Out:
#   File "/tmp/ipython-input-802023256.py", line 3
#     def __init__(self,v,i,p.f):
#                            ^
# SyntaxError: invalid syntax
