# %%
from multiprocessing import pool
def square(n):
  return n*n

with pool(4) as p:
  print(p.map(square,[1,2,3,4,5]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1232129748.py in <cell line: 0>()
#       3   return n*n
#       4
# ----> 5 with pool(4) as p:
#       6   print(p.map(square,[1,2,3,4,5]))
#
# TypeError: 'module' object is not callable

# %%
from scipy optimize import fsolve
def.eq(x):
  return 3*x**2-x-1
root=fsolve(eq,0)
print("Root:",root)
# Out:
#   File "/tmp/ipython-input-3557545621.py", line 1
#     from scipy optimize import fsolve
#                ^
# SyntaxError: invalid syntax
